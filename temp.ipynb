# %%
import pandas as pd

df = pd.read_csv("./data/StreamingQA/train.csv")

df.head()
# Out:
#           qa_id                                           question  \
# 0  train-046509         Where does the UFC always start its fight?
# 1  train-005233  How many customers lost power in Louisiana dur...
# 2  train-040107  How long was the injured young buck stuck on t...
# 3  train-042955  Where did South Australia defeat New South Wales?
# 4  train-047811  When was Bernie Sanders invited for a question...
#
#                                answers answers_additional  question_ts  \
# 0                             the feet                NaN   1517472000
# 1  over 150,000 customers in the state                NaN   1563519600
# 2                         several days                NaN   1576310400
# 3                              the SCG                NaN   1519632000
# 4                        November 2015                NaN   1557212400
#
#    evidence_ts           evidence_id recent_or_past written_or_generated  \
# ...
